# %% [markdown]
# # Your First AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) from Oxford of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load the image dataset and create a pipeline.
# * Build and Train an image classifier on this dataset.
# * Use your trained model to perform inference on flower images.
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.

# %% [markdown]
# ## Import Resources

# %%
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# TODO: Make all necessary imports.
import json
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_datasets as tfds

# %% [markdown]
# ## Load the Dataset
#
# Here you'll use `tensorflow_datasets` to load the [Oxford Flowers 102 dataset](https://www.tensorflow.org/datasets/catalog/oxford_flowers102). This dataset has 3 splits: `'train'`, `'test'`, and `'validation'`.  You'll also need to make sure the training data is normalized and resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet, but you'll still need to normalize and resize the images to the appropriate size.

# %%
# TODO: Load the dataset with TensorFlow Datasets.
# TODO: Create a training set, a validation set and a test set.
(training_set, validation_set, testing_set), dataset_info = tfds.load('oxford_flowers102', split=['train[:80%]', 'train[:20%]', 'test'], as_supervised=True, with_info=True)

training_set.shuffle(len(list(training_set)))
validation_set.shuffle(len(list(training_set)))
testing_set.shuffle(len(list(testing_set)))
# Out:
# ...: 3528 examples [00:26, 129.74 examples/s]
# Generating test examples...: 3542 examples [00:26, 129.71 examples/s]
# Generating test examples...: 3556 examples [00:26, 131.54 examples/s]
# Generating test examples...: 3570 examples [00:26, 123.58 examples/s]
# Generating test examples...: 3583 examples [00:26, 122.64 examples/s]
# Generating test examples...: 3596 examples [00:26, 114.75 examples/s]
# Generating test examples...: 3609 examples [00:27, 116.96 examples/s]
# Generating test examples...: 3621 examples [00:27, 114.96 examples/s]
# Generating test examples...: 3633 examples [00:27, 99.91 examples/s]
# Generating test examples...: 3644 examples [00:27, 96.83 examples/s]
# Generating test examples...: 3656 examples [00:27, 101.95 examples/s]
# Generating test examples...: 3668 examples [00:27, 105.06 examples/s]
# Generating test examples...: 3679 examples [00:27, 101.97 examples/s]
# Generating test examples...: 3691 examples [00:27, 106.57 examples/s]
# Generating test examples...: 3705 examples [00:27, 115.56 examples/s]
# Generating test examples...: 3720 examples [00:28, 123.94 examples/s]
# Generating test examples...: 3735 examples [00:28, 128.82 examples/s]
# Generating test examples...: 3749 examples [00:28, 130.90 examples/s]
# Generating test examples...: 3763 examples [00:28, 128.70 examples/s]
# Generating test examples...: 3777 examples [00:28, 128.98 examples/s]
# Generating test examples...: 3790 examples [00:28, 129.27 examples/s]
# Generating test examples...: 3803 examples [00:28, 122.41 examples/s]
# Generating test examples...: 3817 examples [00:28, 125.93 examples/s]
# Generating test examples...: 3832 examples [00:28, 132.39 examples/s]
# Generating test examples...: 3847 examples [00:29, 137.06 examples/s]
# Generating test examples...: 3862 examples [00:29, 139.76 examples/s]
# Generating test examples...: 3877 examples [00:29, 140.29 examples/s]
# Generating test examples...: 3892 examples [00:29, 139.47 examples/s]
# Generating test examples...: 3906 examples [00:29, 129.54 examples/s]
# Generating test examples...: 3920 examples [00:29, 128.52 examples/s]
# Generating test examples...: 3933 examples [00:29, 127.52 examples/s]
# Generating test examples...: 3946 examples [00:29, 127.50 examples/s]
# Generating test examples...: 3960 examples [00:29, 129.23 examples/s]
# Generating test examples...: 3974 examples [00:30, 131.19 examples/s]
# Generating test examples...: 3988 examples [00:30, 127.82 examples/s]
# Generating test examples...: 4002 examples [00:30, 131.27 examples/s]
# Generating test examples...: 4016 examples [00:30, 130.40 examples/s]
# Generating test examples...: 4030 examples [00:30, 117.96 examples/s]
# Generating test examples...: 4043 examples [00:30, 109.78 examples/s]
# Generating test examples...: 4056 examples [00:30, 113.22 examples/s]
# Generating test examples...: 4070 examples [00:30, 119.36 examples/s]
# Generating test examples...: 4087 examples [00:30, 131.74 examples/s]
# Generating test examples...: 4103 examples [00:31, 137.69 examples/s]
# Generating test examples...: 4119 examples [00:31, 141.58 examples/s]
# Generating test examples...: 4134 examples [00:31, 141.96 examples/s]
# Generating test examples...: 4149 examples [00:31, 141.82 examples/s]
# Generating test examples...: 4164 examples [00:31, 139.38 examples/s]
# Generating test examples...: 4178 examples [00:31, 137.99 examples/s]
# Generating test examples...: 4192 examples [00:31, 137.78 examples/s]
# Generating test examples...: 4206 examples [00:31, 138.02 examples/s]
# Generating test examples...: 4221 examples [00:31, 140.29 examples/s]
# Generating test examples...: 4236 examples [00:31, 140.25 examples/s]
# Generating test examples...: 4251 examples [00:32, 138.27 examples/s]
# Generating test examples...: 4267 examples [00:32, 141.65 examples/s]
# Generating test examples...: 4282 examples [00:32, 140.82 examples/s]
# Generating test examples...: 4297 examples [00:32, 140.63 examples/s]
# Generating test examples...: 4312 examples [00:32, 139.71 examples/s]
# Generating test examples...: 4326 examples [00:32, 138.61 examples/s]
# Generating test examples...: 4340 examples [00:32, 138.21 examples/s]
# Generating test examples...: 4355 examples [00:32, 139.61 examples/s]
# Generating test examples...: 4370 examples [00:32, 141.39 examples/s]
# Generating test examples...: 4385 examples [00:33, 142.65 examples/s]
# Generating test examples...: 4400 examples [00:33, 143.12 examples/s]
# Generating test examples...: 4415 examples [00:33, 144.29 examples/s]
# Generating test examples...: 4430 examples [00:33, 141.81 examples/s]
# Generating test examples...: 4445 examples [00:33, 138.57 examples/s]
# Generating test examples...: 4459 examples [00:33, 135.51 examples/s]
# Generating test examples...: 4473 examples [00:33, 128.29 examples/s]
# Generating test examples...: 4486 examples [00:33, 128.06 examples/s]
# Generating test examples...: 4500 examples [00:33, 129.95 examples/s]
# Generating test examples...: 4514 examples [00:34, 130.58 examples/s]
# Generating test examples...: 4528 examples [00:34, 131.77 examples/s]
# Generating test examples...: 4542 examples [00:34, 129.85 examples/s]
# Generating test examples...: 4556 examples [00:34, 131.61 examples/s]
# Generating test examples...: 4570 examples [00:34, 132.88 examples/s]
# Generating test examples...: 4584 examples [00:34, 134.94 examples/s]
# Generating test examples...: 4598 examples [00:34, 132.17 examples/s]
# Generating test examples...: 4613 examples [00:34, 134.97 examples/s]
# Generating test examples...: 4628 examples [00:34, 137.90 examples/s]
# Generating test examples...: 4643 examples [00:34, 140.19 examples/s]
# Generating test examples...: 4658 examples [00:35, 143.04 examples/s]
# Generating test examples...: 4674 examples [00:35, 146.73 examples/s]
# Generating test examples...: 4689 examples [00:35, 141.46 examples/s]
# Generating test examples...: 4704 examples [00:35, 123.70 examples/s]
# Generating test examples...: 4717 examples [00:35, 124.69 examples/s]
# Generating test examples...: 4731 examples [00:35, 128.48 examples/s]
# Generating test examples...: 4745 examples [00:35, 128.81 examples/s]
# Generating test examples...: 4760 examples [00:35, 133.99 examples/s]
# Generating test examples...: 4775 examples [00:35, 138.15 examples/s]
# Generating test examples...: 4790 examples [00:36, 138.77 examples/s]
# Generating test examples...: 4806 examples [00:36, 143.63 examples/s]
# Generating test examples...: 4821 examples [00:36, 141.38 examples/s]
# Generating test examples...: 4836 examples [00:36, 140.63 examples/s]
# Generating test examples...: 4851 examples [00:36, 139.71 examples/s]
# Generating test examples...: 4866 examples [00:36, 130.39 examples/s]
# Generating test examples...: 4880 examples [00:36, 123.61 examples/s]
# Generating test examples...: 4894 examples [00:36, 126.94 examples/s]
# Generating test examples...: 4907 examples [00:36, 126.40 examples/s]
# Generating test examples...: 4922 examples [00:37, 130.78 examples/s]
# Generating test examples...: 4937 examples [00:37, 135.42 examples/s]
# Generating test examples...: 4951 examples [00:37, 125.62 examples/s]
# Generating test examples...: 4964 examples [00:37, 120.88 examples/s]
# Generating test examples...: 4977 examples [00:37, 112.12 examples/s]
# Generating test examples...: 4989 examples [00:37, 111.28 examples/s]
# Generating test examples...: 5003 examples [00:37, 118.60 examples/s]
# Generating test examples...: 5018 examples [00:37, 125.84 examples/s]
# Generating test examples...: 5033 examples [00:37, 130.41 examples/s]
# Generating test examples...: 5048 examples [00:38, 134.04 examples/s]
# Generating test examples...: 5063 examples [00:38, 137.02 examples/s]
# Generating test examples...: 5078 examples [00:38, 138.36 examples/s]
# Generating test examples...: 5093 examples [00:38, 138.91 examples/s]
# Generating test examples...: 5107 examples [00:38, 137.65 examples/s]
# Generating test examples...: 5121 examples [00:38, 136.75 examples/s]
# Generating test examples...: 5135 examples [00:38, 137.29 examples/s]
# Generating test examples...: 5149 examples [00:38, 136.49 examples/s]
# Generating test examples...: 5164 examples [00:38, 138.41 examples/s]
# Generating test examples...: 5179 examples [00:39, 140.15 examples/s]
# Generating test examples...: 5194 examples [00:39, 141.38 examples/s]
# Generating test examples...: 5209 examples [00:39, 140.61 examples/s]
# Generating test examples...: 5224 examples [00:39, 140.48 examples/s]
# Generating test examples...: 5239 examples [00:39, 138.82 examples/s]
# Generating test examples...: 5254 examples [00:39, 139.62 examples/s]
# Generating test examples...: 5268 examples [00:39, 137.37 examples/s]
# Generating test examples...: 5283 examples [00:39, 139.00 examples/s]
# Generating test examples...: 5297 examples [00:39, 136.54 examples/s]
# Generating test examples...: 5312 examples [00:39, 139.20 examples/s]
# Generating test examples...: 5328 examples [00:40, 144.80 examples/s]
# Generating test examples...: 5343 examples [00:40, 142.57 examples/s]
# Generating test examples...: 5358 examples [00:40, 141.85 examples/s]
# Generating test examples...: 5373 examples [00:40, 140.16 examples/s]
# Generating test examples...: 5388 examples [00:40, 139.39 examples/s]
# Generating test examples...: 5402 examples [00:40, 133.48 examples/s]
# Generating test examples...: 5416 examples [00:40, 130.20 examples/s]
# Generating test examples...: 5431 examples [00:40, 134.21 examples/s]
# Generating test examples...: 5445 examples [00:40, 135.46 examples/s]
# Generating test examples...: 5459 examples [00:41, 136.76 examples/s]
# Generating test examples...: 5474 examples [00:41, 140.20 examples/s]
# Generating test examples...: 5489 examples [00:41, 141.82 examples/s]
# Generating test examples...: 5504 examples [00:41, 138.15 examples/s]
# Generating test examples...: 5518 examples [00:41, 128.39 examples/s]
# Generating test examples...: 5531 examples [00:41, 122.76 examples/s]
# Generating test examples...: 5544 examples [00:41, 116.49 examples/s]
# Generating test examples...: 5557 examples [00:41, 119.14 examples/s]
# Generating test examples...: 5572 examples [00:41, 125.87 examples/s]
# Generating test examples...: 5587 examples [00:42, 131.49 examples/s]
# Generating test examples...: 5604 examples [00:42, 139.62 examples/s]
# Generating test examples...: 5619 examples [00:42, 141.77 examples/s]
# Generating test examples...: 5634 examples [00:42, 140.50 examples/s]
# Generating test examples...: 5649 examples [00:42, 134.02 examples/s]
# Generating test examples...: 5664 examples [00:42, 135.81 examples/s]
# Generating test examples...: 5678 examples [00:42, 136.60 examples/s]
# Generating test examples...: 5692 examples [00:42, 136.79 examples/s]
# Generating test examples...: 5707 examples [00:42, 138.99 examples/s]
# Generating test examples...: 5722 examples [00:42, 140.95 examples/s]
# Generating test examples...: 5737 examples [00:43, 138.36 examples/s]
# Generating test examples...: 5753 examples [00:43, 143.31 examples/s]
# Generating test examples...: 5768 examples [00:43, 142.37 examples/s]
# Generating test examples...: 5783 examples [00:43, 139.74 examples/s]
# Generating test examples...: 5798 examples [00:43, 138.71 examples/s]
# Generating test examples...: 5812 examples [00:43, 137.91 examples/s]
# Generating test examples...: 5826 examples [00:43, 133.17 examples/s]
# Generating test examples...: 5840 examples [00:43, 133.96 examples/s]
# Generating test examples...: 5855 examples [00:43, 138.15 examples/s]
# Generating test examples...: 5871 examples [00:44, 142.00 examples/s]
# Generating test examples...: 5886 examples [00:44, 141.05 examples/s]
# Generating test examples...: 5901 examples [00:44, 136.56 examples/s]
# Generating test examples...: 5915 examples [00:44, 137.14 examples/s]
# Generating test examples...: 5929 examples [00:44, 136.79 examples/s]
# Generating test examples...: 5944 examples [00:44, 137.43 examples/s]
# Generating test examples...: 5958 examples [00:44, 131.74 examples/s]
# Generating test examples...: 5972 examples [00:44, 116.97 examples/s]
# Generating test examples...: 5985 examples [00:44, 118.51 examples/s]
# Generating test examples...: 5999 examples [00:45, 122.61 examples/s]
# Generating test examples...: 6014 examples [00:45, 129.40 examples/s]
# Generating test examples...: 6028 examples [00:45, 131.63 examples/s]
# Generating test examples...: 6042 examples [00:45, 132.50 examples/s]
# Generating test examples...: 6056 examples [00:45, 129.10 examples/s]
# Generating test examples...: 6070 examples [00:45, 127.16 examples/s]
# Generating test examples...: 6084 examples [00:45, 129.30 examples/s]
# Generating test examples...: 6097 examples [00:45, 126.98 examples/s]
# Generating test examples...: 6110 examples [00:45, 121.30 examples/s]
# Generating test examples...: 6123 examples [00:46, 123.03 examples/s]
# Generating test examples...: 6139 examples [00:46, 131.27 examples/s]
#
# Shuffling oxford_flowers102-test.tfrecord...:   0%|          | 0/6149 [00:00<?, ? examples/s]
# Shuffling oxford_flowers102-test.tfrecord...:  22%|██▏       | 1337/6149 [00:00<00:00, 13237.49 examples/s]
# Shuffling oxford_flowers102-test.tfrecord...:  43%|████▎     | 2661/6149 [00:00<00:00, 11913.22 examples/s]
# Shuffling oxford_flowers102-test.tfrecord...:  63%|██████▎   | 3861/6149 [00:00<00:00, 5691.52 examples/s]
# Shuffling oxford_flowers102-test.tfrecord...:  87%|████████▋ | 5329/6149 [00:00<00:00, 7724.35 examples/s]
# Generating splits...:  67%|██████▋   | 2/3 [00:54<00:30, 30.94s/ splits]
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Generating validation examples...: 12 examples [00:00, 118.82 examples/s]
# Generating validation examples...: 24 examples [00:00, 119.51 examples/s]
# Generating validation examples...: 37 examples [00:00, 122.61 examples/s]
# Generating validation examples...: 50 examples [00:00, 119.88 examples/s]
# Generating validation examples...: 63 examples [00:00, 122.97 examples/s]
# Generating validation examples...: 77 examples [00:00, 127.35 examples/s]
# Generating validation examples...: 91 examples [00:00, 127.72 examples/s]
# Generating validation examples...: 107 examples [00:00, 135.96 examples/s]
# Generating validation examples...: 123 examples [00:00, 141.09 examples/s]
# Generating validation examples...: 138 examples [00:01, 139.58 examples/s]
# Generating validation examples...: 153 examples [00:01, 140.17 examples/s]
# Generating validation examples...: 168 examples [00:01, 137.43 examples/s]
# Generating validation examples...: 182 examples [00:01, 133.22 examples/s]
# Generating validation examples...: 196 examples [00:01, 134.37 examples/s]
# Generating validation examples...: 211 examples [00:01, 137.67 examples/s]
# Generating validation examples...: 227 examples [00:01, 141.66 examples/s]
# Generating validation examples...: 243 examples [00:01, 145.69 examples/s]
# Generating validation examples...: 259 examples [00:01, 149.40 examples/s]
# Generating validation examples...: 274 examples [00:02, 145.33 examples/s]
# Generating validation examples...: 289 examples [00:02, 143.77 examples/s]
# Generating validation examples...: 304 examples [00:02, 142.69 examples/s]
# Generating validation examples...: 319 examples [00:02, 142.74 examples/s]
# Generating validation examples...: 334 examples [00:02, 140.78 examples/s]
# Generating validation examples...: 350 examples [00:02, 144.21 examples/s]
# Generating validation examples...: 365 examples [00:02, 143.00 examples/s]
# Generating validation examples...: 380 examples [00:02, 142.15 examples/s]
# Generating validation examples...: 395 examples [00:02, 144.40 examples/s]
# Generating validation examples...: 410 examples [00:02, 141.90 examples/s]
# Generating validation examples...: 425 examples [00:03, 142.19 examples/s]
# Generating validation examples...: 440 examples [00:03, 141.19 examples/s]
# Generating validation examples...: 455 examples [00:03, 141.68 examples/s]
# Generating validation examples...: 470 examples [00:03, 140.05 examples/s]
# Generating validation examples...: 485 examples [00:03, 140.09 examples/s]
# Generating validation examples...: 502 examples [00:03, 146.54 examples/s]
# Generating validation examples...: 518 examples [00:03, 149.54 examples/s]
# Generating validation examples...: 533 examples [00:03, 149.68 examples/s]
# Generating validation examples...: 549 examples [00:03, 151.81 examples/s]
# Generating validation examples...: 565 examples [00:04, 149.81 examples/s]
# Generating validation examples...: 580 examples [00:04, 144.03 examples/s]
# Generating validation examples...: 595 examples [00:04, 142.88 examples/s]
# Generating validation examples...: 610 examples [00:04, 141.67 examples/s]
# Generating validation examples...: 625 examples [00:04, 141.59 examples/s]
# Generating validation examples...: 640 examples [00:04, 143.98 examples/s]
# Generating validation examples...: 655 examples [00:04, 145.30 examples/s]
# Generating validation examples...: 670 examples [00:04, 145.82 examples/s]
# Generating validation examples...: 685 examples [00:04, 142.45 examples/s]
# Generating validation examples...: 700 examples [00:04, 132.56 examples/s]
# Generating validation examples...: 714 examples [00:05, 123.74 examples/s]
# Generating validation examples...: 728 examples [00:05, 126.53 examples/s]
# Generating validation examples...: 741 examples [00:05, 125.76 examples/s]
# Generating validation examples...: 754 examples [00:05, 122.96 examples/s]
# Generating validation examples...: 767 examples [00:05, 117.42 examples/s]
# Generating validation examples...: 779 examples [00:05, 114.40 examples/s]
# Generating validation examples...: 794 examples [00:05, 123.78 examples/s]
# Generating validation examples...: 807 examples [00:05, 119.82 examples/s]
# Generating validation examples...: 820 examples [00:06, 119.65 examples/s]
# Generating validation examples...: 833 examples [00:06, 118.57 examples/s]
# Generating validation examples...: 845 examples [00:06, 113.31 examples/s]
# Generating validation examples...: 857 examples [00:06, 114.83 examples/s]
# Generating validation examples...: 871 examples [00:06, 119.55 examples/s]
# Generating validation examples...: 885 examples [00:06, 124.97 examples/s]
# Generating validation examples...: 901 examples [00:06, 133.11 examples/s]
# Generating validation examples...: 915 examples [00:07, 65.41 examples/s]
# Generating validation examples...: 927 examples [00:07, 73.25 examples/s]
# Generating validation examples...: 939 examples [00:07, 82.09 examples/s]
# Generating validation examples...: 951 examples [00:07, 90.16 examples/s]
# Generating validation examples...: 965 examples [00:07, 101.54 examples/s]
# Generating validation examples...: 980 examples [00:07, 112.78 examples/s]
# Generating validation examples...: 996 examples [00:07, 124.46 examples/s]
# Generating validation examples...: 1011 examples [00:07, 130.32 examples/s]
#
# Shuffling oxford_flowers102-validation.tfrecord...:   0%|          | 0/1020 [00:00<?, ? examples/s]
# Shuffling oxford_flowers102-validation.tfrecord...: 100%|██████████| 1020/1020 [00:00<00:00, 3763.93 examples/s]
# Dataset oxford_flowers102 downloaded and prepared to C:\Users\phill\tensorflow_datasets\oxford_flowers102\2.1.1. Subsequent calls will reuse this data.
# <ShuffleDataset shapes: ((None, None, 3), ()), types: (tf.uint8, tf.int64)>

# %% [markdown]
# ## Explore the Dataset

# %%
# TODO: Get the number of examples in each set from the dataset info.
num_examples_train = dataset_info.splits['train[:80%]'].num_examples
num_examples_validation = dataset_info.splits['train[:20%]'].num_examples
num_examples_test = dataset_info.splits['test'].num_examples

# TODO: Get the number of classes in the dataset from the dataset info.
num_classes = dataset_info.features['label'].num_classes

# %%
# TODO: Print the shape and corresponding label of 3 images in the training set.
for image, label in training_set.take(3):
    tf.print(tuple(image.shape), label)
# Out:
# (500, 667, 3) 72
# (500, 666, 3) 84
# (670, 500, 3) 70

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding image label. 
for image, label in training_set.take(1):
    image = image.numpy().squeeze()
    label = label.numpy()
    
plt.imshow(image, cmap = plt.cm.binary)
plt.colorbar()
plt.title(label)
plt.show()

# %% [markdown]
# ### Label Mapping
#
# You'll also need to load in a mapping from label to category name. You can find this in the file `label_map.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/3.7/library/json.html). This will give you a dictionary mapping the integer coded labels to the actual names of the flowers.

# %%
with open('label_map.json', 'r') as f:
    class_names = json.load(f)

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding class name. 
for image, label in training_set.take(1):
    image = image.numpy().squeeze()
    label = label.numpy()
    
plt.imshow(image, cmap = plt.cm.binary)
plt.colorbar()
plt.title(class_names[str(label)])
plt.show()

# %% [markdown]
# ## Create Pipeline

# %%
# TODO: Create a pipeline for each set.

# %% [markdown]
# # Build and Train the Classifier
#
# Now that the data is ready, it's time to build and train the classifier. You should use the MobileNet pre-trained model from TensorFlow Hub to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students!
#
# Refer to the rubric for guidance on successfully completing this section. Things you'll need to do:
#
# * Load the MobileNet pre-trained network from TensorFlow Hub.
# * Define a new, untrained feed-forward network as a classifier.
# * Train the classifier.
# * Plot the loss and accuracy values achieved during training for the training and validation set.
# * Save your trained model as a Keras model.
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right.
#
# **Note for Workspace users:** One important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module. Also, If your model is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network.

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.

# %% [markdown]
# ## Testing your Network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Print the loss and accuracy values achieved on the entire test set.

# %% [markdown]
# ## Save the Model
#
# Now that your network is trained, save the model so you can load it later for making inference. In the cell below save your model as a Keras model (*i.e.* save it as an HDF5 file).

# %%
# TODO: Save your trained model as a Keras model.

# %% [markdown]
# ## Load the Keras Model
#
# Load the Keras model you saved above.

# %%
# TODO: Load the Keras model

# %% [markdown]
# # Inference for Classification
#
# Now you'll write a function that uses your trained network for inference. Write a function called `predict` that takes an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# The `predict` function will also need to handle pre-processing the input image such that it can be used by your model. We recommend you write a separate function called `process_image` that performs the pre-processing. You can then call the `process_image` function from the `predict` function.
#
# ### Image Pre-processing
#
# The `process_image` function should take in an image (in the form of a NumPy array) and return an image in the form of a NumPy array with shape `(224, 224, 3)`.
#
# First, you should convert your image into a TensorFlow Tensor and then resize it to the appropriate size using `tf.image.resize`.
#
# Second, the pixel values of the input images are typically encoded as integers in the range 0-255, but the model expects the pixel values to be floats in the range 0-1. Therefore, you'll also need to normalize the pixel values.
#
# Finally, convert your image back to a NumPy array using the `.numpy()` method.

# %%
# TODO: Create the process_image function

# %% [markdown]
# To check your `process_image` function we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# The code below loads one of the above images using `PIL` and plots the original image alongside the image produced by your `process_image` function. If your `process_image` function works, the plotted image should be the correct size.

# %%
from PIL import Image

image_path = './test_images/hard-leaved_pocket_orchid.jpg'
im = Image.open(image_path)
test_image = np.asarray(im)

processed_test_image = process_image(test_image)

fig, (ax1, ax2) = plt.subplots(figsize=(10,10), ncols=2)
ax1.imshow(test_image)
ax1.set_title('Original Image')
ax2.imshow(processed_test_image)
ax2.set_title('Processed Image')
plt.tight_layout()
plt.show()

# %% [markdown]
# Once you can get images in the correct format, it's time to write the `predict` function for making inference with your model.
#
# ### Inference
#
# Remember, the `predict` function should take an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# **Note:** The image returned by the `process_image` function is a NumPy array with shape `(224, 224, 3)` but the model expects the input images to be of shape `(1, 224, 224, 3)`. This extra dimension represents the batch size. We suggest you use the `np.expand_dims()` function to add the extra dimension.

# %%
# TODO: Create the predict function

# %% [markdown]
# # Sanity Check
#
# It's always good to check the predictions made by your model to make sure they are correct. To check your predictions we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# In the cell below use `matplotlib` to plot the input image alongside the probabilities for the top 5 classes predicted by your model. Plot the probabilities as a bar graph. The plot should look like this:
#
# <img src='assets/inference_example.png' width=600px>
#
# You can convert from the class integer labels to actual flower names using `class_names`.

# %%
# TODO: Plot the input image along with the top 5 classes
